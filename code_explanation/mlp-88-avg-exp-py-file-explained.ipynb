# %% [markdown]
# This code snippet is a simple Python script that takes command-line arguments and uses them to assign values to the variables alpha and l1_ratio.

# %%
import sys

# %% [markdown]
# This line imports the sys module, which provides access to various system-specific parameters and functions, including command-line arguments.

# %%
alpha = float(sys.argv[1]) if len(sys.argv) > 1 else 0.5

# %% [markdown]
# This line checks if there is at least one command-line argument provided (via sys.argv). If there is, it converts the first argument to a floating-point number and assigns it to the variable alpha. If no argument is provided, the value 0.5 is assigned to alpha.

# %%
l1_ratio = float(sys.argv[2]) if len(sys.argv) > 2 else 0.5

# %% [markdown]
# Similar to the previous line, this line checks if there are at least two command-line arguments provided. If there are, it converts the second argument to a floating-point number and assigns it to the variable l1_ratio. If no second argument is provided, the value 0.5 is assigned to l1_ratio.

# %%
print(alpha, l1_ratio)

# %% [markdown]
# Finally, this line prints the values of alpha and l1_ratio to the console

# %% [markdown]
# In summary, the code allows you to provide two command-line arguments when running the script. These arguments will be used to assign values to the alpha and l1_ratio variables. If no arguments are provided, default values of 0.5 will be used for both variables. The script then prints the values of these variables to the console.

# %% [markdown]
# This script is meant to be run from the command line, allowing you to provide values for alpha and l1_ratio as arguments. It then prints the provided or default values to the console. For example, if you run the script with python script.py 0.2 0.8, it will print 0.2 0.8. If you run it with just python script.py, it will print 0.5 0.5 as the default values are used.
